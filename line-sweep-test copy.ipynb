# %%
import numpy as np
import imageio.v3 as iio
import skimage as ski
import matplotlib.pyplot as plt
from scipy import ndimage
from skimage.morphology import disk, opening, skeletonize

# %%
# Load the whole image
O = iio.imread(uri="removedstamp.tiff")
# Convert to grayscale
O_gray = ski.color.rgb2gray(O)
# Display the image
plt.imshow(O_gray, cmap="gray")
plt.show()

# %%
y, x = O_gray.shape[:2]
print(f"y: {y}, x: {x}")
#Read each line of image until the whole line value = white, then remove all lines with that value and all prior
def horizontal_projection(line_pixels):
    return np.sum(line_pixels, axis=1) # Do the same but for other axis when segmenting graphs

tmp = horizontal_projection (O_gray[3000:13000])

plt.plot(tmp)
# Out:
# y: 15634, x: 2628

# %%
plt.imshow(O_gray[3000:13000])

# %%
# Looking at the other axis to recognize the different graphs

# Save the interval without the headers
headerless_O = O_gray[3000:13000]

def horizontal_projection(line_pixels):
    return np.sum(line_pixels, axis=0)

tmp = horizontal_projection(headerless_O)

#plt.plot(tmp)

O_graph1 = horizontal_projection(headerless_O[:, 50:900]) 
#plt.plot(O_graph1_x)

O_graph2 = horizontal_projection(headerless_O[:, 1000:]) 

# Create three separate subplots
plt.figure(figsize=(10, 8))  # Optional: specify figure size

# First subplot
plt.subplot(3, 1, 1)
plt.plot(tmp)
plt.title('Full Image Projection')

# Second subplot
plt.subplot(3, 1, 2)
plt.plot(O_graph1)
plt.title('1st Graph')

# Thirs subplot
plt.subplot(3, 1, 3)
plt.plot(O_graph2)
plt.title('2nd Graph')

# Add some spacing between subplots
plt.tight_layout()

# Show the plots
plt.show()

# %%
# 1st graph, with the curve
plt.imshow(headerless_O[:, 50:900])

# %%
# 2nd graph with nothing on it, really
plt.imshow(headerless_O[:, 1000:])

# %%
# Cutting the graph into smaller chunks to work on
headerless_O = O[3000:13000]
grahp1 = headerless_O[:, 50:900]

def chunkify(p_pic):
    threshold = 750
    chunks = []
    
    def split(p_pic):
        if p_pic.shape[0] <= threshold:
            chunks.append(p_pic)
        else:
            half = p_pic.shape[0] // 2
            split(p_pic[:half])
            split(p_pic[half:])
    
    split(p_pic)
    return chunks

graph_chunks = chunkify(grahp1)
counter = 0
for i in graph_chunks:
    print(i.shape)
    chunkname = f'second-chunk{counter}'
    print(chunkname)
    iio.imwrite(f"chunks-1st-graph/{chunkname}.tif", i)
    counter += 1
# Out:
# (625, 850, 3)
# second-chunk0
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 26
#      24 chunkname = f'second-chunk{counter}'
#      25 print(chunkname)
# ---> 26 iio.imwrite(f"chrunks-1st-graph/{chunkname}.tif", i)
#      27 counter += 1
#
# File ~/Documents/School/BachelorProject/Digitizing-overlapping-curves/venv/lib/python3.13/site-packages/imageio/v3.py:139, in imwrite(uri, image, plugin, extension, format_hint, **kwargs)
#     104 def imwrite(uri, image, *, plugin=None, extension=None, format_hint=None, **kwargs):
#     105     """Write an ndimage to the given URI.
#     106
#     107     The exact behavior depends on the file type and plugin used. To learn about
#    (...)
#     136
#     137     """
# --> 139     with imopen(
#     140         uri,
#     141         "w",
#     142         legacy_mode=False,
#     143         plugin=plugin,
#     144         format_hint=format_hint,
#     145         extension=extension,
#     146     ) as img_file:
#     147         encoded = img_file.write(image, **kwargs)
#     149     return encoded
#
# File ~/Documents/School/BachelorProject/Digitizing-overlapping-curves/venv/lib/python3.13/site-packages/imageio/core/imopen.py:113, in imopen(uri, io_mode, plugin, extension, format_hint, legacy_mode, **kwargs)
#     111     request.format_hint = format_hint
#     112 else:
# --> 113     request = Request(uri, io_mode, format_hint=format_hint, extension=extension)
#     115 source = "<bytes>" if isinstance(uri, bytes) else uri
#     117 # fast-path based on plugin
#     118 # (except in legacy mode)
#
# File ~/Documents/School/BachelorProject/Digitizing-overlapping-curves/venv/lib/python3.13/site-packages/imageio/core/request.py:249, in Request.__init__(self, uri, mode, extension, format_hint, **kwargs)
#     246     raise ValueError(f"Invalid Request.Mode: {mode}")
#     248 # Parse what was given
# --> 249 self._parse_uri(uri)
#     251 # Set extension
#     252 if extension is not None:
#
# File ~/Documents/School/BachelorProject/Digitizing-overlapping-curves/venv/lib/python3.13/site-packages/imageio/core/request.py:414, in Request._parse_uri(self, uri)
#     412 dn = os.path.dirname(fn)
#     413 if not os.path.exists(dn):
# --> 414     raise FileNotFoundError("The directory %r does not exist" % dn)
#
# FileNotFoundError: The directory '/home/tikki/Documents/School/BachelorProject/Digitizing-overlapping-curves/chrunks-1st-graph' does not exist

# %%
def process_chunks(chunk):
    for i in chunk:
        overlays = []
        # Grayscale
        #print(f'i.shape: \n {i.shape[2]}')
        #print(f'i gray.shape: \n {I_gray.shape}')
        I_grayg = ndimage.gaussian_filter(i, sigma=1)
        # Attempt with OTSU's method
        threshold = ski.filters.threshold_otsu(I_grayg)
        mask = (I_grayg > threshold)
        min_pixels = 500
        row_mask = np.sum(mask, axis=1) < min_pixels
        col_mask = np.sum(mask, axis=0) < min_pixels
        #print(f'row mask: \n {row_mask}')
        # Add a new axis and add the maskings to that as well with np.repeat
        mask_combined = (row_mask[:, np.newaxis] | col_mask[np.newaxis, :])
        #print(f'mask combined: \n {mask_combined}')
        K = np.maximum(i, np.max(i) * mask_combined)
        se = disk(3)
        J = opening(K.mean(axis=2),se)
        S = skeletonize(J<65)
        #plt.figure(figsize=(10,10))
        #plt.subplot(2, 2, 4)
        overlay = np.zeros(i.shape[:2] + (3,), dtype=np.uint8) + 255
        overlay[S] = [255, 0, 0]
        plt.imshow(overlay)
        plt.imshow(i, cmap="gray", alpha=0.2)
        plt.axis("image")
        overlays.append(overlay)
        return overlays


process_chunks(graph_chunks)
# Out:
# /tmp/ipykernel_3925/1739091821.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (625, 850, 3) looks like that of an RGB image.
#   threshold = ski.filters.threshold_otsu(I_grayg)
# [array([[[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         ...,
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]]], shape=(625, 850, 3), dtype=uint8)]

# %%
test = process_chunks(graph_chunks)
plt.imshow(test[0][0:])
# Out:
# /tmp/ipykernel_3925/1739091821.py:9: UserWarning: threshold_otsu is expected to work correctly only for grayscale images; image shape (625, 850, 3) looks like that of an RGB image.
#   threshold = ski.filters.threshold_otsu(I_grayg)
